# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
import os
# %load_ext autoreload
# %autoreload 2
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import warnings
import numpy as np
import pandas as pd
import yaml
import altair as alt
import matplotlib.pyplot as plt
plt.style.use('bmh')

alt.renderers.enable('default')
# Out:
# RendererRegistry.enable('default')

# %%
# !pip install python-dotenv

# %%
from dotenv import load_dotenv
load_dotenv()
OPEN_WEATHER_API_NAME = os.getenv('OPEN_WEATHER_API_NAME')
OPEN_WEATHER_API_KEY = os.getenv('OPEN_WEATHER_API_KEY')
OPEN_WEATHER_API_NAME, OPEN_WEATHER_API_KEY
# Out:
# (None, None)

# %% [markdown]
# # 1) Test API

# %%
import requests
url = api_url = f"http://api.openweathermap.org/data/2.5/forecast?id=524901&appid={OPEN_WEATHER_API_KEY}"
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
import json
response_json = json.loads(response.text)
response_json
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1727190000,
#    'main': {'temp': 292.42,
#     'feels_like': 291.39,
#     'temp_min': 291.28,
#     'temp_max': 292.42,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1002,
#     'humidity': 38,
#     'temp_kf': 1.14},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 71},
#    'wind': {'speed': 2.45, 'deg': 181, 'gust': 5.57},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-24 15:00:00'},
#   {'dt': 1727200800,
#    'main': {'temp': 290.3,
#     'feels_like': 289.12,
#     'temp_min': 288.96,
#     'temp_max': 290.3,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1002,
#     'humidity': 40,
#     'temp_kf': 1.34},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
# ...

# %%
response_json.keys()
# Out:
# dict_keys(['cod', 'message', 'cnt', 'list', 'city'])

# %%
response_json['city']
# Out:
# {'id': 524901,
#  'name': 'Moscow',
#  'coord': {'lat': 55.7522, 'lon': 37.6156},
#  'country': 'RU',
#  'population': 0,
#  'timezone': 10800,
#  'sunrise': 1727147943,
#  'sunset': 1727191436}

# %%
pd.DataFrame(response_json['list'])['dt']
# Out:
# 0     1727190000
# 1     1727200800
# 2     1727211600
# 3     1727222400
# 4     1727233200
# 5     1727244000
# 6     1727254800
# 7     1727265600
# 8     1727276400
# 9     1727287200
# 10    1727298000
# 11    1727308800
# 12    1727319600
# 13    1727330400
# 14    1727341200
# 15    1727352000
# 16    1727362800
# 17    1727373600
# 18    1727384400
# 19    1727395200
# 20    1727406000
# 21    1727416800
# 22    1727427600
# 23    1727438400
# 24    1727449200
# 25    1727460000
# 26    1727470800
# 27    1727481600
# 28    1727492400
# 29    1727503200
# 30    1727514000
# 31    1727524800
# 32    1727535600
# 33    1727546400
# 34    1727557200
# 35    1727568000
# 36    1727578800
# 37    1727589600
# 38    1727600400
# 39    1727611200
# Name: dt, dtype: int64

# %%
def get_api_url(api_key, version, lat=None, long=None):
    
    if version == '2.5':
        # old 
        api_url = f"http://api.openweathermap.org/data/2.5/forecast?id=524901&appid={api_key}"
    else:
        if pd.notnull(lat) & pd.notnull(long):
            api_url = f"https://api.openweathermap.org/data/3.0/onecall?lat={lat}&lon={long}&exclude={part}&appid={api_key}"
        else:
            raise NotImplementedError('Lat and Long values are null')
    return api_url
# Out:
#   Cell In[9], line 8
#     api_url = f"https://api.openweathermap.org/data/3.0/onecall?lat={lat}&lon={lon}&exclude={part}&appid={API key}"
#     ^
# SyntaxError: f-string: invalid syntax. Perhaps you forgot a comma?

# %%
lat = '44.500000'
long = '-89.500000'
OPEN_WEATHER_API_KEY
